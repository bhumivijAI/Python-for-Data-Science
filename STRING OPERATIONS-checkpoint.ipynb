# %% [markdown]
# # WHAT IS INDEXING???
# * Indexing means assessing individual characters(elements) of a string by its position within the string.
#
# * Indexing is of two types: POSIVITE OR NEGITIVE INDEXING.
#
# * Positive indexing starts with 0 or starts from the left side.
#
# * Space is also an character.
#
# * Negitive indexing starts from right hand side,and starts with -15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q = "AYUSHI BOUGHT A PEN!"
q[-6]
q
# Out:
# 'AYUSHI BOUGHT A PEN!'

# %%
q = "AYUSHI BOUGHT A PEN!"
q[-6]
# Out:
# 'A'

# %%
example = "PYTHON IS EASY"
print(example[0])
# Out:
# P

# %%
hp = "an laptop brand"
print(hp[3:4])
# Out:
# l

# %%
hp ="an laptop brand"
print(hp[3])
# Out:
# l

# %%
num1 = "her age is 20"
print(num1[11])
# Out:
# 2

# %%
bhumi = "my name is bhumika sharma "
print(bhumi[14])
# Out:
# m

# %%
example[10]
# Out:
# 'E'

# %%
moon = "moon is beautiful"
print(moon[5])
print(moon[-3])
# Out:
# i
# f

# %%
moon = "moon is beautiful"
print(moon[5],moon[-3])
# Out:
# i f

# %%
error = "string index out of range"
print(error[3]),print(error[-2])
# Out:
# i
# g
# (None, None)

# %%
c = "PYTHON IS EASY"
print(c[-14],c[-10],c[-4],c[-1])
# Out:
# P O E Y

# %%
c = "PYTHON IS EASY"
print(c[0],c[4],c[-4],c[-1])
# Out:
# P O E Y

# %%
animals = "dogs are the pet animals"
print(animals[3],animals[-5])
# Out:
# s i

# %% [markdown]
# # WHAT IS SLICING
#
# * Slicing means accessing a subset of a string based on its indices.
# * Again there is two types of slicing : PoSITIVE AND NEGETIVE
# * the start value must be smaller than the stop value .

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# string syntax [start index : stop index]
example = " PYTHON IS EASY"
example[0:5] # printing pyth cause the stop index value that is coming its getted exclusive so,
             # to print it we have to write one more index number.
# Out:
# ' PYTH'

# %%
bhmi= "HELLO WORLD!"
bhmi[-9:-4]
# Out:
# 'LO WO'

# %%
example = "PYTHON IS EASY"
example[0:6],example[8:10]
# Out:
# ('PYTHON', 'S ')

# %%
n = "i am going to delhi"
n[0],n[2:4],n[11],n[18:14]
# Out:
# ('i', 'am', 't', '')

# %%
n[2:]
# Out:
# 'am going to delhi'

# %%
n[8:]
# Out:
# 'ng to delhi'

# %%
n[4:]
# Out:
# ' going to delhi'

# %%
bhmi[-1:0]
# Out:
# ''

# %%
bhmi[-1:-13:-1]
# Out:
# '!DLROW OLLEH'

# %%
bhmi[-12:20]
# Out:
# 'HELLO WORLD!'

# %%
bhmi[-12:12]
# Out:
# 'HELLO WORLD!'

# %%
example = " python is easy"
example[10:15]
# Out:
# ' easy'

# %%
p= "python is easy "
p[]
# Out:
# 'thon is easy '

# %%
example ="python is easy"
print(example[-100:0])

# %%
example = "python is easy"
print(example[0:-1])
# Out:
# python is eas

# %%
example = "python is easy"
print(example[-20:-1])
# Out:
# python is eas

# %%
example = "python is easy"
print(example[-1:])
# Out:
# y

# %%
x = "PYTHON IS EASY "
print(x[-5:14])
# Out:
# EASY

# %%
x[-8:-8]
# Out:
# ''

# %%
x1 = "python is easy"
x1[-6:-4]
# Out:
# 's '

# %%
x1= "python is easy"
x1[-6:-6]
# Out:
# ''

# %%
example = "python is easy"
example[7:-5]
# Out:
# 'is'

# %%
example = "python is easy"
print(example[-8:-4])
print(example[-6:-4])
# Out:
#  is
# s

# %%
example[1000:10]
# Out:
# ''

# %%
example[2:200]
# Out:
# 'thon is easy'

# %% [markdown]
# # STRIDE
# * String slicing cn also accept a third parameter, the stride , which refers to how maany steps you want to take from the first
#   character of the string.

# %%
x[                :                  :-3]
# Out:
# 'YEIOY'

# %%
x[::-16878989]
# Out:
# 'Y'

# %%
x[]

# %%
# string[start index : stop index : stride/stepvalue]
x = "PYTHON IS EASY"
print(x[0:15:1])
# Out:
# PYTHON IS EASY

# %%
x = "PYTHON IS EASY"       # slice step cannot be zero
x[::0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 x = "PYTHON IS EASY"       # slice step cannot be zero
# ----> 2 x[::0]
#
# ValueError: slice step cannot be zero

# %%
x[-2:                   :-2]
# Out:
# 'SES OTP'

# %%
x = "PYTHON IS EASY "
x[-9:-15:-1]
# Out:
#  NOHTY

# %%
x = "PYTHON IS EASY "
print(x[-1:-6:-1])
# Out:
#  YSAE

# %%
x = ""

# %%
x = "PYTHON IS EASY" # negetive stride
print(x[-9::-1])
# Out:
# NOHTYP

# %%
y = "HELLO WORLD"
print(y[0:5:2])
# Out:
# HLO

# %%
x = "PYTHON IS EASY"
# Out:
# SI

# %% [markdown]
# # strings operations
# * strings methods and functions
# * concatenation of strings

# %%
# .upper() # methods of string 
x.upper()
# Out:
# 'PYTHON IS EASY'

# %%
# .lower()
x.lower()
# Out:
# 'python is easy'

# %%
x = x.upper()
print(x.upper())
print(x)
# Out:
# PYTHON IS EASY
# PYTHON IS EASY

# %%
x = "PYTHON IS EASY"
x = x.lower()
print(x.upper())
print(x)
# Out:
# PYTHON IS EASY
# python is easy

# %%
# .replace()
g = "hello moon"
g = g.replace("o",'z')
g
# Out:
# 'hellz mzzn'

# %%
g = "hello moon"
g = g.replace("hello","moon")
g
# Out:
# 'moon moon'

# %%
g = "hello moon"
g = g.replace(" ","moon") # space is also an character
g
# Out:
# 'hellomoonmoon'

# %%
g = "hello moon"
g = g.replace("hello moon","hello bhumi")
g
# Out:
# 'hello bhumi'

# %%
g = "hello moon"
g = g.replace("","moon") 
g
# Out:
# 'moonhmoonemoonlmoonlmoonomoon moonmmoonomoonomoonnmoon'

# %%
g = "hello moon"
g = g.replace("","+")
g
# Out:
# '+h+e+l+l+o+ +m+o+o+n+'

# %%
g = "hello moon"
g = g.replace(" ","moon").upper().lower()
g
# Out:
# 'hellomoonmoon'

# %%
# .count()
l = "hello bhumi"
l = l.count("hello bhumi")
l
# Out:
# 1

# %%
l = "hello bhumi"
l = l.count("l")
l
# Out:
# 2

# %%
k = "ffffffffffffffffffffffffffffffffffffggggggggggggfffffffffffffffffffffgggggggggggggffffffffffffffffffffffffffffffffffff"
k = k.count("f")
k
# Out:
# 93

# %%
# .endswith
x = "HII YOU"
x.endswith("you")
# Out:
# False

# %%
x.endswith("YOU")
# Out:
# True

# %%
y = "yours name"
y.endswith("e")
# Out:
# True

# %%
y.endswith("m")
# Out:
# False

# %%
y.endswith("ame")
# Out:
# True

# %%
g = "i am here in your city"
g.endswith(y)
# Out:
# False

# %%
# .split()
x = "hello world"
x.split("w")
# Out:
# ['hello ', 'orld']

# %%
x.split(" ")
# Out:
# ['hello', 'world']

# %%
x.split("o")
# Out:
# ['hell', ' w', 'rld']

# %%
x.split("l")
# Out:
# ['he', '', 'o wor', 'd']

# %%
x.split("d")
# Out:
# ['hello worl', '']

# %%
f = "i am typing"
f.split("am") # this type of output is called list
# Out:
# ['i ', ' typing']

# %%
f.split("x")
# Out:
# ['i am typing']

# %%
# .find() -- find the index number of the given letter. index at which 'i'occors for the first time
f.find("i")
# Out:
# 0

# %%
f.find("x") #--giving this output cause the letter isn't in the sentence
# Out:
# -1

# %%
v = "going market"
v.find("t")
# Out:
# 11

# %%
v.find(" ")
# Out:
# 5

# %% [markdown]
# # functions

# %%
# len() --check the length of the string or the sentence.
x = "o"
len(x)
# Out:
# 1

# %%
len("                    python")
# Out:
# 26

# %%
len("                pyhton                  ")
# Out:
# 40

# %% [markdown]
# # TOKENS
#
# * A TOKEN IS THE SMALLEST INDIVIDUAL UNIT IN A PTHON PROGRAM . ALL STATEMENTS AND INSTRUCTIONS IN A PROGRAM ARE BUILD WITH TOKENS.
#
# * KEYWORDS
# * IDENTIFIERS
# * LITERALS
# * OPERATORS
# * PUNCTUATORS

# %% [markdown]
# # LITERALS
#
# * Literals are simply the raw data that is assigned into the variables.

# %% [markdown]
# ###  LITERALS
# 1. Strring literals
#
# 2. Numeric literals
#    a.integer
#    b.float
#    c.complex
#
# 3. Boolean literals
#
# 4. Special literals(none)
#
# 5. Literal collections
#    a.list literal
#    b.tuple literal
#    c.dictionary literal
#    d.set literal

# %% [markdown]
# IDENTIFIERS -- names given to any variable classs,function, method etc.

# %% [markdown]
# KEYWORDS-- are special words which have a unique meaning and purpose in python.
# Keywords cannot be used as variable names , variable names,function names etc

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# PUNCTUATORS -- are symbols that we used to structure the statements. Some commonly used punctuators
# are : "",\,@,{},[],(),#,:,; etc

# %%
help("print")
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# C:\Users\hp\anaconda3\lib\site-packages\caffe2\__init__.py:5: UserWarning: Caffe2 support is not fully enabled in this PyTorch build. Please enable Caffe2 by building PyTorch from source with `BUILD_CAFFE2=1` flag.
#   warnings.warn("Caffe2 support is not fully enabled in this PyTorch build. "
# C:\Users\hp\anaconda3\lib\site-packages\caffe2\proto\__init__.py:17: UserWarning: Caffe2 support is not enabled in this PyTorch build. Please enable Caffe2 by building PyTorch from source with `BUILD_CAFFE2=1` flag.
#   warnings.warn('Caffe2 support is not enabled in this PyTorch build. '
# C:\Users\hp\anaconda3\lib\site-packages\caffe2\proto\__init__.py:17: UserWarning: Caffe2 support is not enabled in this PyTorch build. Please enable Caffe2 by building PyTorch from source with `BUILD_CAFFE2=1` flag.
#   warnings.warn('Caffe2 support is not enabled in this PyTorch build. '
# C:\Users\hp\anaconda3\lib\site-packages\caffe2\python\__init__.py:9: UserWarning: Caffe2 support is not enabled in this PyTorch build. Please enable Caffe2 by building PyTorch from source with `BUILD_CAFFE2=1` flag.
#   warnings.warn('Caffe2 support is not enabled in this PyTorch build. '
# C:\Users\hp\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# C:\Users\hp\anaconda3\lib\site-packages\llvmlite\llvmpy\__init__.py:3: UserWarning: The module `llvmlite.llvmpy` is deprecated and will be removed in the future.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# C:\Users\hp\anaconda3\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# C:\Users\hp\anaconda3\lib\pkgutil.py:92: UserWarning:
#
# viewer requires Qt
#
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# NOTE: Redirects are currently not supported in Windows or MacOs.
# C:\Users\hp\anaconda3\lib\pkgutil.py:107: VisibleDeprecationWarning:
#
# zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
# IPython             conda_build         mmap                socket
# OpenSSL             conda_content_trust mmapfile            socketserver
# PIL                 conda_env           mmsystem            socks
# PyQt5               conda_pack          mock                sockshandler
# TBB                 conda_package_handling modulefinder        sortedcontainers
# __future__          conda_package_streaming mpmath              soupsieve
# _abc                conda_token         msgpack             sphinx
# _aix_support        conda_verify        msilib              spyder
# _argon2_cffi_bindings configparser        msvcrt              spyder_kernels
# _ast                constantly          multipledispatch    sqlalchemy
# _asyncio            contextlib          multiprocessing     sqlite3
# _bisect             contextvars         munkres             sre_compile
# _black_version      contourpy           mypy_extensions     sre_constants
# _blake2             cookiecutter        nacl                sre_parse
# _bootsubprocess     copy                navigator_updater   ssl
# _bz2                copyreg             nbclassic           sspi
# _cffi_backend       crypt               nbclient            sspicon
# _codecs             cryptography        nbconvert           stack_data
# _codecs_cn          cssselect           nbformat            stat
# _codecs_hk          csv                 nest_asyncio        statistics
# _codecs_iso2022     ctypes              netbios             statsmodels
# _codecs_jp          curl                netrc               string
# _codecs_kr          curses              networkx            stringprep
# _codecs_tw          cwp                 nltk                struct
# _collections        cycler              nntplib             subprocess
# _collections_abc    cytoolz             notebook            sunau
# _compat_pickle      daal4py             notebook_shim       sympy
# _compression        dask                nt                  symtable
# _contextvars        dataclasses         ntpath              sys
# _csv                datashader          ntsecuritycon       sysconfig
# _ctypes             datashape           nturl2path          tables
# _ctypes_test        datetime            numba               tabnanny
# _datetime           dateutil            numbergen           tabulate
# _decimal            dbi                 numbers             tarfile
# _distutils_hack     dbm                 numexpr             tbb
# _elementtree        dde                 numpy               tblib
# _functools          debugpy             numpydoc            telnetlib
# _hashlib            decimal             odbc                tempfile
# _heapq              decorator           onedal              tenacity
# _imp                defusedxml          opcode              terminado
# _io                 diff_match_patch    openpyxl            test
# _json               difflib             operator            test_pycosat
# _locale             dill                optparse            text_unidecode
# _lsprof             dis                 os                  textdistance
# _lzma               distributed         packaging           textwrap
# _markupbase         distutils           pandas              this
# _md5                docstring_to_markdown pandocfilters       threading
# _msi                doctest             panel               threadpoolctl
# _multibytecodec     docutils            param               three_merge
# _multiprocessing    email               paramiko            tifffile
# _nsis               encodings           parsel              time
# _opcode             ensurepip           parso               timeit
# _operator           entrypoints         partd               timer
# _osx_support        enum                past                tinycss2
# _overlapped         erfa                pathlib             tkinter
# _pickle             errno               pathspec            tldextract
# _plotly_future_     et_xmlfile          patsy               tlz
# _plotly_utils       executing           pdb                 token
# _py_abc             fastjsonschema      pep8                tokenize
# _pydecimal          faulthandler        perfmon             tokenizers
# _pyio               filecmp             pexpect             toml
# _pyrsistent_version fileinput           pickle              tomli
# _pytest             filelock            pickleshare         tomlkit
# _queue              flake8              pickletools         toolz
# _random             flask               pip                 torch
# _ruamel_yaml        flit_core           pipes               torchgen
# _sha1               fnmatch             pkg_resources       tornado
# _sha256             fontTools           pkginfo             tqdm
# _sha3               fractions           pkgutil             trace
# _sha512             fsspec              platform            traceback
# _signal             ftplib              platformdirs        tracemalloc
# _sitebuiltins       functools           plistlib            traitlets
# _socket             future              plotly              transformers
# _sqlite3            gc                  pluggy              tty
# _sre                genericpath         ply                 turtle
# _ssl                gensim              pooch               turtledemo
# _stat               getopt              poplib              twisted
# _statistics         getpass             posixpath           types
# _string             gettext             poyo                typing
# _strptime           glob                pprint              typing_extensions
# _struct             glob2               profile             ujson
# _symtable           graphlib            prometheus_client   unicodedata
# _system_path        greenlet            prompt_toolkit      unidecode
# _testbuffer         gzip                protego             unittest
# _testcapi           h5py                pstats              urllib
# _testconsole        hamcrest            psutil              urllib3
# _testimportmultiple hashlib             pty                 uu
# _testinternalcapi   heapdict            ptyprocess          uuid
# _testmultiphase     heapq               pure_eval           venv
# _thread             hmac                pvectorc            w3lib
# _threading_local    holoviews           py                  warnings
# _tkinter            html                py_compile          watchdog
# _tracemalloc        http                pyasn1              wave
# _uuid               huggingface_hub     pyasn1_modules      wcwidth
# _warnings           hvplot              pyclbr              weakref
# _weakref            hyperlink           pycodestyle         webbrowser
# _weakrefset         idlelib             pycosat             webencodings
# _win32sysloader     idna                pycparser           websocket
# _winapi             imagecodecs         pyct                werkzeug
# _winxptheme         imageio             pycurl              whatthepatch
# _xxsubinterpreters  imagesize           pydispatch          wheel
# _yaml               imaplib             pydoc               widgetsnbextension
# _zoneinfo           imblearn            pydoc_data          win2kras
# abc                 imghdr              pydocstyle          win32api
# adodbapi            imp                 pyexpat             win32clipboard
# afxres              importlib           pyflakes            win32com
# aifc                importlib_metadata  pygments            win32con
# alabaster           incremental         pylab               win32console
# anaconda_navigator  inflection          pylint              win32cred
# anaconda_project    iniconfig           pylint_venv         win32crypt
# antigravity         inspect             pyls_spyder         win32cryptcon
# anyio               intake              pylsp               win32ctypes
# appdirs             intervaltree        pylsp_black         win32event
# argon2              io                  pylsp_jsonrpc       win32evtlog
# argparse            ipaddress           pyodbc              win32evtlogutil
# array               ipykernel           pyparsing           win32file
# arrow               ipykernel_launcher  pyrsistent          win32gui
# ast                 ipython_genutils    pytest              win32gui_struct
# astroid             ipywidgets          pythoncom           win32help
# astropy             isapi               pytoolconfig        win32inet
# asttokens           isort               pytz                win32inetcon
# asynchat            isympy              pyviz_comms         win32job
# asyncio             itemadapter         pywin               win32lz
# asyncore            itemloaders         pywin32_bootstrap   win32net
# atexit              itertools           pywin32_testutil    win32netcon
# atomicwrites        itsdangerous        pywintypes          win32pdh
# attr                jedi                pywt                win32pdhquery
# attrs               jellyfish           qdarkstyle          win32pdhutil
# audioop             jinja2              qstylizer           win32pipe
# automat             jinja2_time         qtawesome           win32print
# autopep8            jmespath            qtconsole           win32process
# babel               joblib              qtpy                win32profile
# backcall            json                queue               win32ras
# backports           json5               queuelib            win32rcparser
# base64              jsonpatch           quopri              win32security
# bcrypt              jsonpointer         random              win32service
# bdb                 jsonschema          rasutil             win32serviceutil
# binaryornot         jupyter             re                  win32timezone
# binascii            jupyter_client      regcheck            win32trace
# binhex              jupyter_console     regex               win32traceutil
# binstar_client      jupyter_core        regutil             win32transaction
# bisect              jupyter_server      repo_cli            win32ts
# black               jupyterlab          reprlib             win32ui
# blackd              jupyterlab_plotly   requests            win32uiole
# bleach              jupyterlab_pygments requests_file       win32verstamp
# blib2to3            jupyterlab_server   requests_toolbelt   win32wnet
# bokeh               jupyterlab_widgets  rlcompleter         win_inet_pton
# boltons             jwt                 rope                wincertstore
# bottleneck          keyring             rtree               winerror
# brotli              keyword             ruamel_yaml         winioctlcon
# bs4                 kiwisolver          runpy               winnt
# builtins            lazy_object_proxy   sched               winperf
# bz2                 lib2to3             scipy               winpty
# cProfile            libarchive          scrapy              winreg
# caffe2              libfuturize         seaborn             winsound
# calendar            libpasteurize       secrets             winxpgui
# certifi             lief                select              winxptheme
# cffi                linecache           selectors           wrapt
# cgi                 llvmlite            send2trash          wsgiref
# cgitb               locale              service_identity    xarray
# chardet             locket              servicemanager      xdrlib
# charset_normalizer  logging             setuptools          xlwings
# chunk               lxml                shelve              xml
# click               lz4                 shlex               xmlrpc
# cloudpickle         lzma                shutil              xxlimited
# clyent              mailbox             signal              xxlimited_35
# cmath               mailcap             sipbuild            xxsubtype
# cmd                 markdown            site                yaml
# code                markupsafe          six                 yapf
# codecs              marshal             skimage             yapftests
# codeop              math                sklearn             zict
# collections         matplotlib          sklearnex           zipapp
# colorama            matplotlib_inline   slugify             zipfile
# colorcet            mccabe              smart_open          zipimport
# colorsys            menuinst            smtpd               zipp
# comm                mimetypes           smtplib             zlib
# commctrl            mistune             snappy              zmq
# compileall          mkl                 sndhdr              zoneinfo
# concurrent          mkl_fft             sniffio             zope
# conda               mkl_random          snowballstemmer     zstandard
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
